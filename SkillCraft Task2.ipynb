# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")#builtin dataset

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.isnull().head()
# Out:
#    survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0     False   False  False  False  False  False  False     False  False
# 1     False   False  False  False  False  False  False     False  False
# 2     False   False  False  False  False  False  False     False  False
# 3     False   False  False  False  False  False  False     False  False
# 4     False   False  False  False  False  False  False     False  False
#
#      who  adult_male   deck  embark_town  alive  alone
# 0  False       False   True        False  False  False
# 1  False       False  False        False  False  False
# 2  False       False   True        False  False  False
# 3  False       False  False        False  False  False
# 4  False       False   True        False  False  False

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'].fillna(titanic['age'].median(),inplace=True)# Filling the null values in age with median of the data.

# %%
titanic['embarked'].fillna(titanic['embarked'].mode()[0],inplace=True)# Filling the null values in embark_town with mode of the data.

# %%
titanic.drop(columns=['deck'],inplace=True)

# %%
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
titanic['pclass']=titanic['pclass'].astype('category')

# %%
titanic['pclass'].dtype
# Out:
# CategoricalDtype(categories=[1, 2, 3], ordered=False)

# %%
titanic['survived']=titanic['survived'].astype('bool')

# %%
titanic['survived'].dtype
# Out:
# dtype('bool')

# %%
titanic.head()
# Out:
#    survived pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0     False      3    male  22.0      1      0   7.2500        S  Third
# 1      True      1  female  38.0      1      0  71.2833        C  First
# 2      True      3  female  26.0      0      0   7.9250        S  Third
# 3      True      1  female  35.0      1      0  53.1000        S  First
# 4     False      3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
titanic.duplicated().sum()# finding duplictes
# Out:
# 116

# %%
#droping duplicate
titanic.drop_duplicates(inplace=True)

# %%
titanic.duplicated().sum()# finding duplictes
# Out:
# 0

# %%
print(f"Number of rows after removing duplicates: {titanic.shape[0]}")
# Out:
# Number of rows after removing duplicates: 775

# %%
print(titanic.describe(include='object'))  # Summary for categorical columns
# Out:
#          sex embarked  who  embark_town alive
# count    775      775  775          773   775
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     483      562  443          560   455

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Survived Column:

# %%
sns.countplot(x='survived', data=titanic,palette='pastel' )
plt.title('Survival Count')
plt.ylabel('Count')
plt.xticks([0, 1], ['Did Not Survive', 'Survived'])
plt.show()

# %% [markdown]
# ### 2. Age Distribution and Frequency

# %%
sns.histplot(titanic['age'].dropna(), kde=True, bins=20, color='blue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Inference :
# Age group of 25 to 30 is majority

# %%
# Filter data where passengers did not survive
unsurvived_data = titanic[titanic['survived'] == False]  # Boolean condition

# %%
unsurvived_data
# Out:
#      survived pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0       False      3    male  22.0      1      0   7.2500        S   Third
# 4       False      3    male  35.0      0      0   8.0500        S   Third
# 5       False      3    male  28.0      0      0   8.4583        Q   Third
# 6       False      1    male  54.0      0      0  51.8625        S   First
# 7       False      3    male   2.0      3      1  21.0750        S   Third
# ..        ...    ...     ...   ...    ...    ...      ...      ...     ...
# 882     False      3  female  22.0      0      0  10.5167        S   Third
# 883     False      2    male  28.0      0      0  10.5000        S  Second
# 885     False      3  female  39.0      0      5  29.1250        Q   Third
# 888     False      3  female  28.0      1      2  23.4500        S   Third
# 890     False      3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
sns.histplot(unsurvived_data['age'].dropna(), kde=True, bins=20, color='blue')
plt.title('Age Distribution for Unsurvived')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The most unsurvived ones are in the age group of 25 to 30

# %%
# Filter data where passengers survived
survived_data = titanic[titanic['survived'] == True]  # Boolean condition
survived_data
# Out:
#      survived pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1        True      1  female  38.0      1      0  71.2833        C   First
# 2        True      3  female  26.0      0      0   7.9250        S   Third
# 3        True      1  female  35.0      1      0  53.1000        S   First
# 8        True      3  female  27.0      0      2  11.1333        S   Third
# 9        True      2  female  14.0      1      0  30.0708        C  Second
# ..        ...    ...     ...   ...    ...    ...      ...      ...     ...
# 875      True      3  female  15.0      0      0   7.2250        C   Third
# 879      True      1  female  56.0      0      1  83.1583        C   First
# 880      True      2  female  25.0      0      1  26.0000        S  Second
# 887      True      1  female  19.0      0      0  30.0000        S   First
# 889      True      1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
sns.histplot(survived_data['age'].dropna(), kde=True, bins=20, color='blue')
plt.title('Age Distribution for Survived')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The most survived is from 25 to 28(approx)

# %%
sns.countplot(data=titanic, x='sex', hue='survived')
plt.title('Sex wise analysis')
plt.show()

# %% [markdown]
# Males are less survived than Females

# %% [markdown]
# ### Correlation Analysis

# %%
corr = titanic.select_dtypes(include=['float64', 'int64']).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Map')
plt.show()

# %% [markdown]
# ### Survival by Class

# %%
sns.countplot(data=titanic, x='pclass', hue='survived')
plt.title('Survival by Class')
plt.show()

# %% [markdown]
# Most survived are 1st class travellers
